# %%
import pickle
import numpy as np
import string
import re
from pyvi import ViTokenizer
import matplotlib.pyplot as plt
import nltk
#from nltk.tokenize import word_tokenize

# %%
pattern = r'[' + string.punctuation +']'
#'[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]'

# %%
sentences = ('Tháng 5/2018, C04 phá chuyên án 128Y do Vũ Hoàng Oanh cầm đầu, thu giữ 74 kg ma túy, bắt 8 đối tượng trong đường dây. Tuy nhiên, Vũ Hoàng Oanh bỏ trốn sang nước ngoài. C04 ra quyết định truy nã đặc biệt Vũ Hoàng Oanh về tội mua bán trái phép chất ma túy và có lệnh truy nã quốc tế của Interpol. Sau khi sang nước ngoài, Vũ Hoàng Oanh thu nạp nhiều đàn em bị truy nã, đối tượng cộm cán hình thành đường dây mua bán ma túy từ khu vực Tam giác vàng về TP.HCM và Hải Phòng tiêu thụ. Thủ đoạn của các đối tượng là giấu ma túy trong các lốc máy ô tô đã qua sử dụng, rồi thuê Võ Văn Hậu (35 tuổi, ở Long An) vận chuyển từ nước ngoài về TP.HCM tập kết ở kho hàng của Nguyễn Anh Bảo Quốc (50 tuổi, ở Bình Tân, TP.HCM) và kho hàng của Nguyễn Duy Khánh ở huyện Hóc Môn, TP.HCM. Tại kho hàng, Quốc thuê Nguyễn Thành Thắng (32 tuổi) và Đỗ Thế Phong (53 tuổi) tháo các lốc máy lấy ma túy rồi giao cho các khách mua sỉ trên địa bàn TP.HCM. Ngoài ra, ma túy còn được vận chuyển về chi nhánh Công ty vận tải Bắc Việt ở quận 12, TP.HCM, sau đó vận chuyển ra trụ sở chính công ty ở Hà Nội giao cho Phạm Thế Anh (32 tuổi), Giám đốc Công ty cổ phần thương mại và xuất nhập khẩu Sky House để vận chuyển ra Hải Phòng tiêu thụ. Trinh sát xác định ngày 13/9, các đối tượng sẽ chuyển 4 lốc máy về kho của Nguyễn Anh Bảo Quốc. Nhận định thời cơ phá án đã đến, Cục Cảnh sát điều tra tội phạm về ma túy đã huy động hơn 100 cán bộ, chiến sỹ chia làm nhiều tổ công tác phá án. Ngày 13/9, C04 chủ trì, phối hợp với Cục Kỹ thuật nghiệp vụ, các đơn vị nghiệp vụ của Bộ Công an, Công an TP.HCM bắt quả tang Nguyễn Thành Thắng đang vận chuyển trái phép chất ma túy, thu giữ 20 kg ma túy tổng hợp. Thắng khai đi giao ma túy theo sự chỉ đạo của Quốc, nơi nhận sẽ được Thắng thông báo trước, ám tín hiệu để giao ma túy là tờ tiền chụp ảnh vào điện thoại di động sau đó đối chiếu trùng khớp số seri. Khám xét khẩn cấp chỗ ở của Nguyễn Thành Thắng, công an thu giữ 26 bánh heroine, khối lượng 9 kg. Tại TP.HCM, cơ quan điều tra bắt giữ Nguyễn Anh Bảo Quốc, Nguyễn Thanh Sơn, Nguyễn Tri Phương, Nguyễn Văn Út Hậu, Nguyễn Thị Năm, Đỗ Thế Phong và Nguyễn Ngọc Duy. Tại Hà Nội, công an bắt giữ Phạm Thế Anh, Giám đốc Công ty cổ phần thương mại và xuất nhập khẩu Sky House, thu giữ 2 kg ma túy tổng hợp và 2 xe ô tô. Tổng cộng ban chuyên án đã thu giữ 75 kg ma túy các loại. Tiếp tục mở rộng điều tra, ban chuyên án xác định, Nguyễn Văn Nam (32 tuổi, ở Hải Phòng) và Nguyễn Thị Thanh Thủy (25 tuổi, ở Hưng Yên) đã 23 lần nhận 91 lốc máy ô tô có cất giấu tổng số 1,5 tấn ma túy vận chuyển qua biên giới từ nước ngoài về TP.HCM thuê kho bãi cất giấu, sau đó thuê Phạm Thế Anh vận chuyển về Hà Nội rồi đưa đi Hải Phòng tiêu thụ. Thông qua các biện pháp nghiệp vụ xác định, sau khi các mắt xích trong đường dây bị bắt giữ, Nam và Thủy bỏ trốn vào phía Nam, sau đó xuất cảnh qua đường tiểu ngạch sang nước ngoài lẩn trốn. Dưới sự chỉ đạo của Thứ trưởng Nguyễn Duy Ngọc, C04 phối hợp với các đơn vị nghiệp vụ xác minh, lần theo dấu vết bỏ trốn của các đối tượng. Sau một thời gian dài trinh sát, ngày 23/9, Cục Cảnh sát điều tra tội phạm về ma túy đã phối hợp cùng Cơ quan đại diện Bộ Công an tại nước ngoài và các lực lượng chức năng của nước bạn bắt giữ Nguyễn Văn Nam, Nguyễn Thị Thanh Thủy (là 2 đối tượng trong chuyên án), Nguyễn Ngọc Sơn (là đối tượng truy nã đặc biệt về ma túy của Công an tỉnh Quảng Ninh) và Vũ Hoàng Oanh (đối tượng truy nã quốc tế về ma túy). Ngày 24/9 tại Hải Phòng, Cục Cảnh sát điều tra tội phạm về ma túy thực hiện lệnh giữ người trong trường hợp khẩn cấp, khám xét khẩn cấp chỗ ở về hành vi mua bán, vận chuyển trái phép chất ma túy đối với 6 đối tượng khác trong chuyên án gồm: Nguyễn Văn Quảng (26 tuổi); Nguyễn Văn Vũ (32 tuổi), Tạ Thị Duyên (29 tuổi), Đào Văn Quỳnh (37 tuổi), Nguyễn Văn Cuối (47 tuổi), Lương Thị Thu Huyền (25 tuổi). Ban chuyên án thu giữ 1 ô tô, dụng cụ để tháo các lốc máy, 21 điện thoại di động, sổ ghi chép liên quan đến hoạt động vận chuyển, mua bán trái phép chất ma túy cùng nhiều tài liệu liên quan đến vụ án. Tiếp tục mở rộng vụ án, ngày 15/10 tại TP.HCM, C04 bắt quả tang Nguyễn Xuân Thành (32 tuổi) ở TP.HCM khi đang điều khiển xe máy giao ma túy cho khách, thu giữ tại chỗ 2 kg ma túy tổng hợp. Khám xét 3 căn hộ của Thành đứng tên và thuê tại TP.HCM công an thu giữ thêm 7.000 viên ma túy, 3 kg ma túy tổng hợp, 1.000 túi ma túy nước vui, 2 kg ma túy dạng bột và nhiều tài liệu liên quan. Đồng thời, C04 thi hành lệnh bắt giữ và khám xét nhà Bàng A Đạt (40 tuổi, ở TP.HCM), thu giữ 1,4 kg ma túy tổng hợp; Võ Bá Nghĩa (32 tuổi, ở Đồng Nai) và Phan Thanh Bình (25 tuổi, ở TP.HCM). Đến nay, Cơ quan Cảnh sát điều tra Bộ Công an đã khởi tố, bắt giữ 29 đối tượng, thu giữ 131 kg ma túy các loại, bước đầu làm rõ các đối tượng mua bán, tiêu thụ trái phép trên 1,6 tấn ma túy. Như vậy, chỉ trong thời gian ngắn, C04 đã chủ trì phối hợp với các đơn vị nghiệp vụ của Bộ, Công an các đơn vị địa phương, Cơ quan đại diện Bộ Công an tại nước ngoài quyết liệt tấn công tội phạm đến cùng, đấu tranh, khám phá thành công tổ chức tội phạm mua bán, vận chuyển trái phép ma túy xuyên quốc gia từ nước ngoài về Việt Nam với quy mô đặc biệt lớn, phương thức, thủ đoạn tinh vi, xảo quyệt do nhiều đối tượng, ở nhiều tỉnh thành tham gia. Đặc biệt có sự chỉ đạo, điều hành của Vũ Hoàng Oanh (Oanh "Hà") là đối tượng cộm cán, có lệnh truy nã quốc tế về ma túy.')

# %%
print(sentences)
# Out:
# Tháng 5/2018, C04 phá chuyên án 128Y do Vũ Hoàng Oanh cầm đầu, thu giữ 74 kg ma túy, bắt 8 đối tượng trong đường dây. Tuy nhiên, Vũ Hoàng Oanh bỏ trốn sang nước ngoài. C04 ra quyết định truy nã đặc biệt Vũ Hoàng Oanh về tội mua bán trái phép chất ma túy và có lệnh truy nã quốc tế của Interpol. Sau khi sang nước ngoài, Vũ Hoàng Oanh thu nạp nhiều đàn em bị truy nã, đối tượng cộm cán hình thành đường dây mua bán ma túy từ khu vực Tam giác vàng về TP.HCM và Hải Phòng tiêu thụ. Thủ đoạn của các đối tượng là giấu ma túy trong các lốc máy ô tô đã qua sử dụng, rồi thuê Võ Văn Hậu (35 tuổi, ở Long An) vận chuyển từ nước ngoài về TP.HCM tập kết ở kho hàng của Nguyễn Anh Bảo Quốc (50 tuổi, ở Bình Tân, TP.HCM) và kho hàng của Nguyễn Duy Khánh ở huyện Hóc Môn, TP.HCM. Tại kho hàng, Quốc thuê Nguyễn Thành Thắng (32 tuổi) và Đỗ Thế Phong (53 tuổi) tháo các lốc máy lấy ma túy rồi giao cho các khách mua sỉ trên địa bàn TP.HCM. Ngoài ra, ma túy còn được vận chuyển về chi nhánh Công ty vận tải Bắc Việ
# ...

# %%
words_in = ViTokenizer.tokenize(sentences)
#Replace every pattern with the space
words_in = re.sub(pattern, '', words_in)
number_of_words_in = len(words_in.split())

# %%
#Remove spaces at the beginning and at the end of the string
sentences=sentences.strip()

# %%
sentences
# Out:
# 'Tháng 5/2018, C04 phá chuyên án 128Y do Vũ Hoàng Oanh cầm đầu, thu giữ 74 kg ma túy, bắt 8 đối tượng trong đường dây. Tuy nhiên, Vũ Hoàng Oanh bỏ trốn sang nước ngoài. C04 ra quyết định truy nã đặc biệt Vũ Hoàng Oanh về tội mua bán trái phép chất ma túy và có lệnh truy nã quốc tế của Interpol. Sau khi sang nước ngoài, Vũ Hoàng Oanh thu nạp nhiều đàn em bị truy nã, đối tượng cộm cán hình thành đường dây mua bán ma túy từ khu vực Tam giác vàng về TP.HCM và Hải Phòng tiêu thụ. Thủ đoạn của các đối tượng là giấu ma túy trong các lốc máy ô tô đã qua sử dụng, rồi thuê Võ Văn Hậu (35 tuổi, ở Long An) vận chuyển từ nước ngoài về TP.HCM tập kết ở kho hàng của Nguyễn Anh Bảo Quốc (50 tuổi, ở Bình Tân, TP.HCM) và kho hàng của Nguyễn Duy Khánh ở huyện Hóc Môn, TP.HCM. Tại kho hàng, Quốc thuê Nguyễn Thành Thắng (32 tuổi) và Đỗ Thế Phong (53 tuổi) tháo các lốc máy lấy ma túy rồi giao cho các khách mua sỉ trên địa bàn TP.HCM. Ngoài ra, ma túy còn được vận chuyển về chi nhánh Công ty vận tải Bắc Vi
# ...

# %%
sentences = nltk.sent_tokenize(sentences)
print(sentences)
number_of_sentences = len(sentences)
print("Number_of_sentences: " + str(number_of_sentences))
# Out:
# ['Tháng 5/2018, C04 phá chuyên án 128Y do Vũ Hoàng Oanh cầm đầu, thu giữ 74 kg ma túy, bắt 8 đối tượng trong đường dây.', 'Tuy nhiên, Vũ Hoàng Oanh bỏ trốn sang nước ngoài.', 'C04 ra quyết định truy nã đặc biệt Vũ Hoàng Oanh về tội mua bán trái phép chất ma túy và có lệnh truy nã quốc tế của Interpol.', 'Sau khi sang nước ngoài, Vũ Hoàng Oanh thu nạp nhiều đàn em bị truy nã, đối tượng cộm cán hình thành đường dây mua bán ma túy từ khu vực Tam giác vàng về TP.HCM và Hải Phòng tiêu thụ.', 'Thủ đoạn của các đối tượng là giấu ma túy trong các lốc máy ô tô đã qua sử dụng, rồi thuê Võ Văn Hậu (35 tuổi, ở Long An) vận chuyển từ nước ngoài về TP.HCM tập kết ở kho hàng của Nguyễn Anh Bảo Quốc (50 tuổi, ở Bình Tân, TP.HCM) và kho hàng của Nguyễn Duy Khánh ở huyện Hóc Môn, TP.HCM.', 'Tại kho hàng, Quốc thuê Nguyễn Thành Thắng (32 tuổi) và Đỗ Thế Phong (53 tuổi) tháo các lốc máy lấy ma túy rồi giao cho các khách mua sỉ trên địa bàn TP.HCM.', 'Ngoài ra, ma túy còn được vận chuyển về chi nhánh Côn
# ...

# %%
import sklearn.model_selection
from gensim.models import KeyedVectors 


w2v = KeyedVectors.load_word2vec_format("data/vi-300-5-30000-10-loss1.vec")

# %%
vocab = w2v.key_to_index

# %%
print(vocab)
# Out:
# {'và': 0, 'có': 1, 'là': 2, 'của': 3, 'không': 4, 'cho': 5, 'người': 6, 'được': 7, 'trong': 8, 'các': 9, 'một': 10, 'những': 11, 'với': 12, 'đã': 13, 'để': 14, 'khi': 15, 'bạn': 16, 'cũng': 17, 'đến': 18, 'này': 19, 'nhiều': 20, 'sẽ': 21, 'tôi': 22, 'đó': 23, 'phải': 24, 'ở': 25, 'ra': 26, 'làm': 27, 'bị': 28, 'như': 29, 'lại': 30, 'về': 31, 'con': 32, 'thì': 33, 'có_thể': 34, 'vào': 35, 'mình': 36, 'anh': 37, 'đi': 38, 'nên': 39, 'mà': 40, 'hơn': 41, 'nhưng': 42, 'còn': 43, 'ngày': 44, 'biết': 45, 'chỉ': 46, 'rất': 47, 'từ': 48, 'bệnh': 49, 'sau': 50, 'cô': 51, 'trên': 52, 'nhà': 53, 'mẹ': 54, 'vì': 55, 'ăn': 56, 'trẻ': 57, 'năm': 58, 'tuổi': 59, 'chồng': 60, 'việc': 61, 'thấy': 62, 'cần': 63, 'em': 64, 'nước': 65, 'giúp': 66, 'nói': 67, 'sự': 68, 'đang': 69, 'mới': 70, 'hay': 71, 'chị': 72, 'vẫn': 73, 'bé': 74, 'lên': 75, 'gì': 76, 'khác': 77, 'cả': 78, 'ấy': 79, 'da': 80, 'gây': 81, 'rồi': 82, 'nhau': 83, 'loại': 84, 'do': 85, 'tại': 86, 'khiến': 87, 'nhất': 88, 'hai': 89, 'thuốc'
# ...

# %%
sentences_vec_array = []
for sentence in sentences:
    sentence = re.sub(pattern, '', sentence)
    sentence = ViTokenizer.tokenize(sentence).strip()
    #Split a string into a list 
    words = sentence.split()
    sentence_vec = np.zeros((300))
    for word in words:
        if word in vocab:
            sentence_vec+=w2v.key_to_index[word]
    sentences_vec_array.append(sentence_vec)

# %%
sentences_vec_array
# Out:
# [array([84549., 84549., 84549., 84549., 84549., 84549., 84549., 84549.,
#         84549., 84549., 84549., 84549., 84549., 84549., 84549., 84549.,
#         84549., 84549., 84549., 84549., 84549., 84549., 84549., 84549.,
#         84549., 84549., 84549., 84549., 84549., 84549., 84549., 84549.,
#         84549., 84549., 84549., 84549., 84549., 84549., 84549., 84549.,
#         84549., 84549., 84549., 84549., 84549., 84549., 84549., 84549.,
#         84549., 84549., 84549., 84549., 84549., 84549., 84549., 84549.,
#         84549., 84549., 84549., 84549., 84549., 84549., 84549., 84549.,
#         84549., 84549., 84549., 84549., 84549., 84549., 84549., 84549.,
#         84549., 84549., 84549., 84549., 84549., 84549., 84549., 84549.,
#         84549., 84549., 84549., 84549., 84549., 84549., 84549., 84549.,
#         84549., 84549., 84549., 84549., 84549., 84549., 84549., 84549.,
#         84549., 84549., 84549., 84549., 84549., 84549., 84549., 84549.,
# ...

# %%
print(words)
# Out:
# ['Đặc_biệt', 'có', 'sự', 'chỉ_đạo', 'điều_hành', 'của', 'Vũ', 'Hoàng', 'Oanh', 'Oanh', 'Hà', 'là', 'đối_tượng', 'cộm', 'cán', 'có', 'lệnh', 'truy_nã', 'quốc_tế', 'về', 'ma_túy']

# %%
from sklearn.cluster import KMeans

n_clusters = 9
#n_clusters = round(number_of_sentences/2)
kmeans = KMeans(n_clusters=n_clusters)
kmeans = kmeans.fit(sentences_vec_array)
from sklearn.metrics import pairwise_distances_argmin_min

avg = []
for j in range(n_clusters):
    idx = np.where(kmeans.labels_ == j)[0]
    avg.append(np.mean(idx))

closest, _  = pairwise_distances_argmin_min(kmeans.cluster_centers_, sentences_vec_array)
ordering = sorted(range(n_clusters), key=lambda k: avg[k])
summary = '\n'.join([sentences[closest[idx]] for idx in ordering])

# %%
print(summary)
# Out:
# Tuy nhiên, Vũ Hoàng Oanh bỏ trốn sang nước ngoài.
# Tại kho hàng, Quốc thuê Nguyễn Thành Thắng (32 tuổi) và Đỗ Thế Phong (53 tuổi) tháo các lốc máy lấy ma túy rồi giao cho các khách mua sỉ trên địa bàn TP.HCM.
# C04 ra quyết định truy nã đặc biệt Vũ Hoàng Oanh về tội mua bán trái phép chất ma túy và có lệnh truy nã quốc tế của Interpol.
# Dưới sự chỉ đạo của Thứ trưởng Nguyễn Duy Ngọc, C04 phối hợp với các đơn vị nghiệp vụ xác minh, lần theo dấu vết bỏ trốn của các đối tượng.
# Thắng khai đi giao ma túy theo sự chỉ đạo của Quốc, nơi nhận sẽ được Thắng thông báo trước, ám tín hiệu để giao ma túy là tờ tiền chụp ảnh vào điện thoại di động sau đó đối chiếu trùng khớp số seri.
# Ngoài ra, ma túy còn được vận chuyển về chi nhánh Công ty vận tải Bắc Việt ở quận 12, TP.HCM, sau đó vận chuyển ra trụ sở chính công ty ở Hà Nội giao cho Phạm Thế Anh (32 tuổi), Giám đốc Công ty cổ phần thương mại và xuất nhập khẩu Sky House để vận chuyển ra Hải Phòng tiêu thụ.
# ...

# %%
words_out = ViTokenizer.tokenize(summary)
#words_out = re.sub(pattern, '', words_out)
print(words_out)
number_of_words_out = len(words_out.split())
# Out:
# Tuy_nhiên , Vũ Hoàng Oanh bỏ trốn sang nước_ngoài .
#  Tại kho hàng , Quốc thuê Nguyễn_Thành_Thắng ( 32 tuổi ) và Đỗ_Thế_Phong ( 53 tuổi ) tháo các lốc máy lấy ma_túy rồi giao cho các khách mua_sỉ trên địa_bàn TP. HCM.
#  C04 ra quyết_định truy_nã đặc_biệt Vũ Hoàng Oanh về tội mua_bán trái_phép chất ma_túy và có lệnh truy_nã quốc_tế của Interpol .
#  Dưới sự chỉ_đạo của Thứ_trưởng Nguyễn Duy_Ngọc , C04 phối_hợp với các đơn_vị nghiệp_vụ xác_minh , lần theo dấu_vết bỏ trốn của các đối_tượng .
#  Thắng khai đi giao ma_túy theo sự chỉ_đạo của Quốc , nơi nhận sẽ được Thắng thông_báo trước , ám tín_hiệu để giao ma_túy là tờ tiền chụp ảnh vào điện_thoại_di_động sau đó đối_chiếu trùng khớp số seri .
#  Ngoài_ra , ma_túy còn được vận_chuyển về chi_nhánh Công_ty vận_tải Bắc Việt ở quận 12 , TP. HCM , sau đó vận_chuyển ra trụ_sở chính công_ty ở Hà_Nội giao cho Phạm_Thế_Anh ( 32 tuổi ) , Giám_đốc Công_ty cổ_phần thương_mại và xuất nhập_khẩu Sky_House để vận_chuyển ra Hải_Phòng tiêu_thụ .
# ...

# %%
print("number_of_words_in: " + str(number_of_words_in))
print("number_of_words_out: " + str(number_of_words_out))
print("div: " + str((number_of_words_out/number_of_words_in)*100))
# Out:
# number_of_words_in: 837
# number_of_words_out: 349
# div: 41.69653524492234
